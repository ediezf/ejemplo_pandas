# %%
import pandas as pd

# %%
datos = pd.read_csv('survey_results_public.csv')

# %%
datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  str
#  2   MainBranch                           89184 non-null  str
#  3   Age                                  89184 non-null  str
#  4   Employment                           87898 non-null  str
#  5   RemoteWork                           73810 non-null  str
#  6   CodingActivities                     73764 non-null  str
#  7   EdLevel                              87973 non-null  str
#  8   LearnCode                            87663 non-null  str
#  9   LearnCodeOnline                      70084 non-null  str
#  10  LearnCodeCoursesCert                 37076 non-null  str
# ...

# %%
datos
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
 # COUNTRY ascendente, ConvertedCompYearly descendente
datos.sort_values(by=["Country", "ConvertedCompYearly"], ascending=[True, False])
# Out:
#        ResponseId     Q120                      MainBranch                Age  \
# 88347       88348  I agree  I am a developer by profession    25-34 years old
# 86038       86039  I agree  I am a developer by profession    35-44 years old
# 1334         1335  I agree  I am a developer by profession    18-24 years old
# 57361       57362  I agree  I am a developer by profession    18-24 years old
# 17872       17873  I agree  I am a developer by profession    25-34 years old
# ...           ...      ...                             ...                ...
# 88820       88821  I agree                   None of these    35-44 years old
# 88828       88829  I agree                   None of these    25-34 years old
# 88830       88831  I agree                   None of these    18-24 years old
# 89028       89029  I agree                   None of these    45-54 years old
# 89159       89160  I agree                   None of these  Prefer not to say
#
# ...

# %%
datos["ConvertedCompYearly"].nlargest(25)
# Out:
# 53268    74351432.0
# 77848    73607918.0
# 66223    72714292.0
# 28121    57513831.0
# 19679    36573181.0
# 55102    17612921.0
# 80586    11000000.0
# 83679    10319366.0
# 47797     9915585.0
# 88347     9203683.0
# 64972     9070484.0
# 770       9000000.0
# 34996     7435143.0
# 66757     6377931.0
# 69889     6229051.0
# 81960     5354477.0
# 79949     4451577.0
# 56804     3508749.0
# 88903     3000000.0
# 10518     2875692.0
# 51182     2700000.0
# 16631     2592024.0
# 16081     2500000.0
# 40855     2434514.0
# 16666     2400000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
datos['Country'].str.upper()
# Out:
# 0                                 NaN
# 1            UNITED STATES OF AMERICA
# 2            UNITED STATES OF AMERICA
# 3            UNITED STATES OF AMERICA
# 4                         PHILIPPINES
#                      ...
# 89179                          BRAZIL
# 89180                         ROMANIA
# 89181                          ISRAEL
# 89182                     SWITZERLAND
# 89183    IRAN, ISLAMIC REPUBLIC OF...
# Name: Country, Length: 89184, dtype: str

# %%
import numpy as np

# %%
pip install matplotlib
# Out:
# WARNING: Ignoring invalid distribution ~ip (/home/ediezf/Develop/Labs.Python/ejemplo_pandas/.venv/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ip (/home/ediezf/Develop/Labs.Python/ejemplo_pandas/.venv/lib/python3.12/site-packages)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 671.4 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 999.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 7.1 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 3.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 6.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 7.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 1.4 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# %matplotlib inline

# %%
boxplot = datos.boxplot(figsize=(5, 5))

# %%
datos.boxplot(column = ['ConvertedCompYearly'], grid = False)
# Out:
# <Axes: >

# %%
datos.drop(datos[datos['ConvertedCompYearly'] > 200000].index, inplace=True)

# %%
datos.drop(datos[datos['ConvertedCompYearly'] < 2000].index, inplace=True)

# %%
datos.boxplot(column = ['ConvertedCompYearly'])
# Out:
# <Axes: >

# %%
histograma = datos.hist(column='ConvertedCompYearly', 
                   bins=10, grid=True, figsize=(12,8), color='#55bf91', zorder=2, rwidth=0.9)

# %%
paises = (datos.Country.value_counts())

# %%
paises.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
prog_paises =  (paises.nlargest(10))

# %%
prog_paises.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
prog_paises.plot.bar(title='Cantidad de programadores por país', xlabel='Paises', ylabel='# de programadores', colormap='plasma')
# Out:
# <Axes: title={'center': 'Cantidad de programadores por país'}, xlabel='Paises', ylabel='# de programadores'>

# %%
filtro = datos['Country'] == 'Spain'
print(datos.loc[filtro])
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 24             25  I agree                     I am a developer by profession
# 29             30  I agree                     I am a developer by profession
# 69             70  I agree                     I am a developer by profession
# 180           181  I agree                     I am a developer by profession
# 290           291  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 88397       88398  I agree                     I am a developer by profession
# 88474       88475  I agree                              I am learning to code
# 88505       88506  I agree  I am not primarily a developer, but I write co...
# 89152       89153  I agree                     I am a developer by profession
# 89172       89173  I agree                     I am a developer by profession
#
# ...

# %%
exportar = (datos.loc[filtro])

# %%
exportar.head()
# Out:
#      ResponseId     Q120                      MainBranch              Age  \
# 24           25  I agree  I am a developer by profession  35-44 years old
# 29           30  I agree  I am a developer by profession  35-44 years old
# 69           70  I agree  I am a developer by profession  25-34 years old
# 180         181  I agree  I am a developer by profession  18-24 years old
# 290         291  I agree  I am a developer by profession  25-34 years old
#
#                              Employment                            RemoteWork  \
# 24                  Employed, full-time  Hybrid (some remote, some in-person)
# 29                  Employed, full-time                                Remote
# 69   Not employed, but looking for work                                   NaN
# 180                 Employed, full-time  Hybrid (some remote, some in-person)
# 290                 Employed, full-time  Hybrid (some remote, some in-person)
#
# ...

# %%
exportar.to_csv('datos-exportados.csv')
